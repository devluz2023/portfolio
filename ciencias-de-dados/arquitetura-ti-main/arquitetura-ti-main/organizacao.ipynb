# %% [markdown]
# <a href="https://colab.research.google.com/github/devluz2023/arquitetura-ti/blob/main/organizacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Objetivo, aplicar COBIT como modelo de governança, ITl como modelo de gestão de serviços, lean como modelo de redutivo,
## Scrum para desenvolvimento de software, Pmbok para projetos grandes relacionados a terceiros, e COSO para controle, e
## ISO 27001, ISO 27002, ISO 22301, ISO 27005  e OWASP para prática de desenvolvimento de software seguro
## CMMI e MPS.BR para medir o nivel de maturidade dos processos da área.
from itertools import product
import pandas as pd
from IPython.display import display

processos_cobit=[
    'Avaliar',
    'Direcionar',
    'Monitorar' ,
    'Alinhar',
    'Planejar',
    'Organizar'
    ]

habilitadores_cobit=[
    'Princípios',
    'Políticas',
    'Frameworks',
    'Processos',
    'Estruturas Organizacionais',
    'Cultura',
    'Ética',
    'Comportamento',
    'Informação',
    'Serviços',
    'Infraestrutura',
    'Aplicações',
    'Pessoas',
    'Habilidades',
    'Competências'
]
principios_cobit = [
    "Princípio 1: Fornecer Valor para o Negócio",
    "Princípio 2: Alinhar com Objetivos",
    "Princípio 3: Habilitar uma Abordagem Holística",
    "Princípio 4: Separar Governança de Gerenciamento",
    "Princípio 5: Aplicar um Framework Integrado",
    "Princípio 6: Habilitar uma Cultura",
    "Princípio 7: Garantir a Transparência"
]

fundamentos_cobit = [
    "Fundamento 1: Processos de Governança de TI",
    "Fundamento 2: Princípios de Governança de TI",
    "Fundamento 3: Estrutura Organizacional de Governança de TI",
    "Fundamento 4: Cultura, Ética e Comportamento",
    "Fundamento 5: Informação como Ativo de Governança",
    "Fundamento 6: Serviços, Infraestrutura e Aplicações",
    "Fundamento 7: Pessoas, Habilidades e Competências"
]

# Geração de todas as combinações possíveis

principios_da_itil = [
    "Foco no Valor do Negócio",
    "Comece de Onde Você Está",
    "Progrida Iterativamente com Feedback",
    "Colabore e Promova Visibilidade",
    "Pense e Trabalhe de Forma Holística",
    "Mantenha-o Simples e Prático",
    "Otimize e Automatize",
    "Esteja Pronto para Aprender"
]



fundamentos_da_itil = [
    'Gerenciamento do Cumprimento de Requisição',
    'Gerenciamento de Incidentes',
    'Gerenciamento do Conhecimento',
    'Gerenciamento do Portfólio',
    'Gerenciamento do Catálogo de Serviço',
    'Gerenciamento de Nível de Serviço',
    'Gerenciamento de Problema',
    'Gerenciamento de Mudança',
    'Gerenciamento de Liberação e Implantação',
    'Gerenciamento de Configuração',
    'Gerenciamento de Ativos de Serviço',
    'Gerenciamento de Eventos',
    'Gerenciamento de Capacidade',
    'Gerenciamento de Disponibilidade',
    'Gerenciamento de Continuidade de Serviços de TI',
    'Gerenciamento Financeiro'


]
componentes_itil = [
  'Estratégia de serviço ITIL V3',
  'Desenho do serviço ITIL V3',
  'Transição de serviço ITIL V3',
  'Operação de serviço ITIL V3',
  'Melhoria contínua de serviço ITIL V3'
]


fundamentos_iso_27001 = []
processos_iso_27001 = []
principios_iso_27001 = [
    'Estabelecimento do SGSI',
    'Implementação de controles de segurança',
    'comprometimento da direção'
]

fundamentos_iso_27002 = []
processos_iso_27002 = []
principios_iso_27002 = [
    'Politicas de segurança da informação',
    'Organização da segurança da informação',
    'Avaliação e gestão de risco',
    'Segurança em recuros humanos',
    'Segurança Física e do meio ambiente',
    'Gerenciamento das comunicações e operações',
    'Controle de acesso',
    'Gestão de Incidentes de segurança da informação',
    'Gestão da continuidade do negócio',
    'conformidade'
]
fundamentos_iso_27003 = []
processos_iso_27003 = []
principios_iso_27003= [
    'Criptografia',
    'Aquisição, desenvolvimento e manutenção de sistemas de informação'
]
fundamentos_iso_27005 = []
processos_iso_27005 = []
principios_iso_27005=[
    "Contexto organizacional",
    'Alinhamento com processo de gestão de risco da organização',
    'Seleção de abordagens para tratamento de riscos',
    'Monitoramento e análise críticas'
]
fundamentos_iso_22301 = []
processos_iso_22301 = []
principios_iso_22301 =[
    'Liderança e comprometimento',
    'Politicas de conitnuidade de negócios',
    'Avaliação de riscos e oportunidades',
    'planehamento de continuidade de negócios',
    'Avaliação de desempenho'
]


# Exibição das primeiras 10 combinações
owasp_praticas = [
    'A1: Injeção SQL',
    'A2: Quebra de Autenticação e Sessão',
    'A3: Exposição de Dados Sensíveis',
    'A4: XML External Entities (XXE)',
    'A5: Quebra de Controle de Acesso',
    'A6: Configuração Incorreta de Segurança',
    'A7: Cross-Site Scripting (XSS)',
    'A8: Deserialização Insegura',
    'A9: Uso de Componentes com Vulnerabilidades Conhecidas',
    'A10: Logging e Monitoramento Insuficientes'
]

principios_do_coso=[]
fundamentos_do_coso=[]
gerenciamento_do_coso=[]
coso=[
    'Ambiente de controle',
    'Avaliação de risco',
    'Atividades de controle',
    'Informação e comunicação',
    'Monitoramento'
    ]

pmbok_fases=[]
pmbok_processos=[]

cmmi_niveis=[]
cmmi_processos_dos_niveis=[]

mps_br_niveis=[]
mpbs_br_processso=[]


fase_engenharia_de_software=[]
fase_scrum=[]

processos_intosai=[]
etaps_intosais=[]


fase_lean = [
    "Identificação de Oportunidades",
    "Treinamento e Educação",
    "Mapeamento do Fluxo de Valor (Value Stream Mapping)",
    "Implementação das Melhorias",
    "Monitoramento e Controle",
    "Melhoria Contínua (Kaizen)"
]

processos_lean = [
    "Mapeamento do Fluxo de Valor (Value Stream Mapping)",
    "5S (Classificação, Organização, Limpeza, Padronização e Autodisciplina)",
    "Just-in-Time (JIT)",
    "Kanban",
    "Kaizen (Melhoria Contínua)",
    "Padronização de Trabalho",
    "Poka-Yoke (Prova de Erros)",
    "Gerenciamento Visual",
    "Trabalho em Equipe e Envolvimento dos Funcionários"
]

principios_lean = [
    "Identificar o Valor do Cliente (Value)",
    "Mapear o Fluxo de Valor (Value Stream Mapping)",
    "Criar Fluxo Contínuo (Flow)",
    "Estabelecer Puxar (Pull)",
    "Buscar a Perfeição (Perfection)",
    "Envolvimento dos Funcionários (Respect for People)",
    "Reduzir Desperdícios (Eliminate Waste)",
    "Melhoria Contínua (Continuous Improvement)",
    "Flexibilidade (Flexibility)",
    "Entregar Qualidade (Deliver Quality)"
]

# %%
combinacoes_cobit = list(product(principios_da_itil, fundamentos_da_itil, principios_cobit, fundamentos_cobit))


# Criar um DataFrame a partir das combinações do COBIT
df_cobit = pd.DataFrame(combinacoes_cobit, columns=["Processos COBIT", "Habilitadores COBIT", "Princípios COBIT", "Fundamentos COBIT"])

# Exibir o DataFrame
df_cobit.head(4410)
# Out:
#      Processos COBIT Habilitadores COBIT  \
# 0            Avaliar          Princípios
# 1            Avaliar          Princípios
# 2            Avaliar          Princípios
# 3            Avaliar          Princípios
# 4            Avaliar          Princípios
# ...              ...                 ...
# 4405       Organizar        Competências
# 4406       Organizar        Competências
# 4407       Organizar        Competências
# 4408       Organizar        Competências
# 4409       Organizar        Competências
#
#                                 Princípios COBIT  \
# 0     Princípio 1: Fornecer Valor para o Negócio
# 1     Princípio 1: Fornecer Valor para o Negócio
# 2     Princípio 1: Fornecer Valor para o Negócio
# 3     Princípio 1: Fornecer Valor para o Negócio
# 4     Princípio 1: Fornecer Valor para o Negócio
# ...                                          ...
# 4405       Princípio 7: Garantir a Transparência
# 4406       Princípio 7: Garantir a Transparência
# ...

# %%
combinacoes_itil = list(product(principios_da_itil, fundamentos_da_itil, componentes_itil))


# Criar um DataFrame a partir das combinações da ITIL
df_itil = pd.DataFrame(combinacoes_itil, columns=["Principios da ITIL", "Fundamentos da ITil", "Componentes da Itil"])

# Exibir o DataFrame
df_itil.head(4410)
# Out:
#               Principios da ITIL                         Fundamentos da ITil  \
# 0       Foco no Valor do Negócio  Gerenciamento do Cumprimento de Requisição
# 1       Foco no Valor do Negócio  Gerenciamento do Cumprimento de Requisição
# 2       Foco no Valor do Negócio  Gerenciamento do Cumprimento de Requisição
# 3       Foco no Valor do Negócio  Gerenciamento do Cumprimento de Requisição
# 4       Foco no Valor do Negócio  Gerenciamento do Cumprimento de Requisição
# ..                           ...                                         ...
# 635  Esteja Pronto para Aprender                    Gerenciamento Financeiro
# 636  Esteja Pronto para Aprender                    Gerenciamento Financeiro
# 637  Esteja Pronto para Aprender                    Gerenciamento Financeiro
# 638  Esteja Pronto para Aprender                    Gerenciamento Financeiro
# 639  Esteja Pronto para Aprender                    Gerenciamento Financeiro
#
#                       Componentes da Itil
# ...

# %%
combinacoes = list(product(processos_cobit, habilitadores_cobit, componentes_itil, gerenciamento_itil))
lean_combinations = [
    {"fase_lean": fase, "principios_lean": principio, "processo": processo}
    for fase, principio, processo in product(fase_lean, principios_lean, processos_lean)
]

# %%
df_lean = pd.DataFrame(lean_combinations)

# Exibir o DataFrame completo
# Configurar para exibir todas as colunas do DataFrame
df_lean.head(540)
# Out:
#                           fase_lean                         principios_lean  \
# 0    Identificação de Oportunidades  Identificar o Valor do Cliente (Value)
# 1    Identificação de Oportunidades  Identificar o Valor do Cliente (Value)
# 2    Identificação de Oportunidades  Identificar o Valor do Cliente (Value)
# 3    Identificação de Oportunidades  Identificar o Valor do Cliente (Value)
# 4    Identificação de Oportunidades  Identificar o Valor do Cliente (Value)
# ..                              ...                                     ...
# 535      Melhoria Contínua (Kaizen)    Entregar Qualidade (Deliver Quality)
# 536      Melhoria Contínua (Kaizen)    Entregar Qualidade (Deliver Quality)
# 537      Melhoria Contínua (Kaizen)    Entregar Qualidade (Deliver Quality)
# 538      Melhoria Contínua (Kaizen)    Entregar Qualidade (Deliver Quality)
# 539      Melhoria Contínua (Kaizen)    Entregar Qualidade (Deliver Quality)
#
#                                               processo
# ...

# %%
principios_da_itil = [
    "Foco no Valor do Negócio",
    "Comece de Onde Você Está",
    "Progrida Iterativamente com Feedback",
    "Colabore e Promova Visibilidade",
    "Pense e Trabalhe de Forma Holística",
    "Mantenha-o Simples e Prático",
    "Otimize e Automatize",
    "Esteja Pronto para Aprender"
]

fundamentos_da_itil = [
    "Abordagem de Serviço",
    "Modelos de Processo",
    "Princípios e Marcos",
    "Funções e Responsabilidades",
    "Processos"
]

# %%
df_combinacoes = pd.DataFrame(combinacoes)

# Exibir o DataFrame completo
df_combinacoes
# # Exportar o DataFrame para um arquivo Excel
# df_combinacoes.to_excel('combinacoes.xlsx', index=False)
# Out:
#               0             1                                     2  \
# 0       Avaliar    Princípios         Estratégia de serviço ITIL V3
# 1       Avaliar    Princípios         Estratégia de serviço ITIL V3
# 2       Avaliar    Princípios         Estratégia de serviço ITIL V3
# 3       Avaliar    Princípios         Estratégia de serviço ITIL V3
# 4       Avaliar    Princípios         Estratégia de serviço ITIL V3
# ...         ...           ...                                   ...
# 7195  Organizar  Competências  Melhoria contínua de serviço ITIL V3
# 7196  Organizar  Competências  Melhoria contínua de serviço ITIL V3
# 7197  Organizar  Competências  Melhoria contínua de serviço ITIL V3
# 7198  Organizar  Competências  Melhoria contínua de serviço ITIL V3
# 7199  Organizar  Competências  Melhoria contínua de serviço ITIL V3
#
#                                                     3
# 0     Gerenciamento de Continuidade de Serviços de TI
# ...

# %%
combinacoes2 = list(product( owasp_praticas, principios_iso_27001, principios_iso_27002, principios_iso_27003, principios_iso_27005,
                          principios_iso_22301,  coso))
df_combinacoes = pd.DataFrame(combinacoes2)

# Exibir o DataFrame completo
df_combinacoes.head(10000)
# # Exportar o DataFrame para um arquivo Excel
df_combinacoes.to_excel('combinacoes2.xlsx', index=False)
